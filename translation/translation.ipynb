# %%
from question_translation import translate_whole_df
import pandas as pd
import numpy as np

# %% [markdown]
# ## Set data paths

# %%
test_set_path = "../data/test.jsonl"
train_set_path = "../data/train.jsonl"
translated_test_set_path = "../data/translated_test.csv"
translated_train_set_path = "../data/translated_train.csv"

# %% [markdown]
# ## Read files

# %%
df_test = pd.read_json(test_set_path, lines = True)
df_train = pd.read_json(train_set_path, lines = True)

# %% [markdown]
# ## Translate test set

# %%
translate_whole_df (df_test, translated_test_set_path , batch_size = 100)
# Out:
#   0%|          | 0/158 [00:00<?, ?it/s]c:\Users\33631\Documents\Etudes\centrale 3A\projet recherche\2021-table-question-answering\venv\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#   1%|          | 1/158 [00:59<2:35:39, 59.49s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48728/3467378517.py in <module>
# ----> 1 translate_whole_df (df_test, translated_test_set_path , batch_size = 100)
#
# ...

# %% [markdown]
# ## Translate train set

# %%
translate_whole_df (df_train, translated_train_set_path , batch_size = 100)
